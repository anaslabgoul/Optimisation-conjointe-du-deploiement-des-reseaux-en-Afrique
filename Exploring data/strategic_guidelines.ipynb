# %%
import pandas as pd

# %%
strategic_guidelines= pd.read_csv("STRATEGIC_GUIDELINES.csv", sep=";")

# %%
strategic_guidelines.sample(5)
# Out:
#    TIME_SLOTS   QA
# 0           1  0.1
# 3           4  0.4
# 4           5  0.5
# 1           2  0.2
# 2           3  0.3

# %% [markdown]
# Chaque année, le régulateur impose un pourcentage minimal de population qui doit être couvert par la nouvelle technologie (5G).

# %% [markdown]
# DATA MAPPING

# %% [markdown]
# TIME_SLOTS -> t
# QA -> QA_t
