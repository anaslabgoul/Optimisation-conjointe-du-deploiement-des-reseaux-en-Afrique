# %%
import pandas as pd

# %%
demande = pd.read_csv("DEMAND.csv", sep=";")

# %%
demande.sample(4)
# Out:
#    TIME_SLOTS     3G     4G     5G
# 2           3  0.002  0.005  0.008
# 3           4  0.002  0.005  0.009
# 4           5  0.003  0.006  0.010
# 1           2  0.002  0.005  0.007

# %% [markdown]
# $D_{NG}$ --> demande moyenne
