# %%
import pandas as pd

# %%
operational_limits= pd.read_csv("OPERATIONAL_LIMITS.csv", sep=";")

# %%
operational_limits.sample(5)
# Out:
#    TIME_SLOTS  MAX_NUMBER_OF_DEPLOYMENTS  MAX_NUMBER_OF_SITE_CONSTRUCTION
# 3           4                         50                                0
# 4           5                         50                                0
# 0           1                         50                                0
# 1           2                         50                                0
# 2           3                         50                                0

# %% [markdown]
# Le nombre maximal de sites pouvant être déployés à chaque intervalle de temps t ∈ T, noté Zₜ

# %% [markdown]
# MAPPING THE DATA

# %% [markdown]
# - MAX_NUMBER_OF_DEPLOYMENTS -> Zₜ
#
# - MAX_NUMBER_OF_SITE_CONSTRUCTION -> Ne correspond à rien dans le modèle
