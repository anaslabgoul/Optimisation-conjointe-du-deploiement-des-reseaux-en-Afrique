# %% [markdown]
# PARAMETERS;VALUES
#
# TIME_SLOTS;6
#
# NEWEST_TECHNOLOGY;5G
#
# NEWEST_OFFER;o5G
#
# THRESHOLD;0.7
#
# OBJECTIVE;SUBSCRIBERS
#
# SOLVER;cplex
#
# TIME_LIMIT_IN_SECONDS;1800
#
# TARGET_OPERATOR;ORANGE

# %% [markdown]
# Our Target operator is Orange.
#
# we want to apply NG = {5G}
#
# Tlimits =
