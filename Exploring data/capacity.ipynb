# %%
import pandas as pd

# %%
capacity = pd.read_csv("CAPACITY.csv", sep=";")

# %%
capacity.sample(5)
# Out:
#    TIME_SLOTS    3G    4G    5G
# 2           2   750  2000  2750
# 5           5   500  1750  3250
# 1           1  1000  2000  2500
# 4           4   500  1750  3250
# 0           0  1000  2000  2500

# %% [markdown]
# capacité totale disponible pour chaque technologie, en fonction de ces TIME_SLOTS.

# %% [markdown]
# Au fil du temps, la capacité disponible pour la nouvelle génération (5G) augmente, tandis que celle des anciennes technologies (3G/4G) diminue.

# %% [markdown]
# CAPA NG = 750+2000+2750 = 5500
